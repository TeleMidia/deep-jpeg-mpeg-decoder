# %% [markdown]
# ### Dependences

# %%
import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt
from IPython.display import clear_output

from lib.models.card import card
import lib.utils as utils

# %% [markdown]
# ### Loading experiment data

# %%
#set experiment ID
EXP_ID = "card"
utils.create_experiment_folders(EXP_ID)
utils.load_experiment_data()

# %% [markdown]
# ### Model instantiation

# %%
model = card().model
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs (InputLayer)             [(None, 96, 96, 3)]  0
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice (Tens [(None, 96, 96, 1)]  0           inputs[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_1 (Te [(None, 96, 96, 1)]  0           inputs[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_2 (Te [(None, 96, 96, 1)]  0           inputs[0][0]
# __________________________________________________________________________________________________
# Y_DCT2C (Sequential)            (None, 12, 12, 64)   4160        tf_op_layer_strided_slice[0][0]
# __________________________________________________________________________________________________
# Cr_DCT2C (Sequential)           (None, 12, 12, 64)   4160        tf_op_layer_strided_slice_1[0][0]
# __________________________________________________________________________________________________
# Cb_DCT2C (Sequential)           (None, 12, 12, 64)   4160        tf_op_layer_strided_slice_2[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_0 ( (None, 12, 12, 64)   147648      Y_DCT2C[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_20  (None, 12, 12, 64)   147648      Cr_DCT2C[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_40  (None, 12, 12, 64)   147648      Cb_DCT2C[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 12, 12, 64)   0           WideActivationResidualBlock_0[0][
#                                                                  Y_DCT2C[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_20[0]
#                                                                  Cr_DCT2C[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_40[0]
#                                                                  Cb_DCT2C[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_1 ( (None, 12, 12, 64)   147648      add[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_21  (None, 12, 12, 64)   147648      add_21[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_41  (None, 12, 12, 64)   147648      add_42[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 12, 12, 64)   0           WideActivationResidualBlock_1[0][
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_21[0]
#                                                                  add_21[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_41[0]
#                                                                  add_42[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_2 ( (None, 12, 12, 64)   147648      add_1[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_22  (None, 12, 12, 64)   147648      add_22[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_42  (None, 12, 12, 64)   147648      add_43[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 12, 12, 64)   0           WideActivationResidualBlock_2[0][
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_22[0]
#                                                                  add_22[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_42[0]
#                                                                  add_43[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_3 ( (None, 12, 12, 64)   147648      add_2[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_23  (None, 12, 12, 64)   147648      add_23[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_43  (None, 12, 12, 64)   147648      add_44[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 12, 12, 64)   0           WideActivationResidualBlock_3[0][
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_23[0]
#                                                                  add_23[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_43[0]
#                                                                  add_44[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_4 ( (None, 12, 12, 64)   147648      add_3[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_24  (None, 12, 12, 64)   147648      add_24[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_44  (None, 12, 12, 64)   147648      add_45[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 12, 12, 64)   0           WideActivationResidualBlock_4[0][
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_24[0]
#                                                                  add_24[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_44[0]
#                                                                  add_45[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_5 ( (None, 12, 12, 64)   147648      add_4[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_25  (None, 12, 12, 64)   147648      add_25[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_45  (None, 12, 12, 64)   147648      add_46[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 12, 12, 64)   0           WideActivationResidualBlock_5[0][
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_25[0]
#                                                                  add_25[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_45[0]
#                                                                  add_46[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_6 ( (None, 12, 12, 64)   147648      add_5[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_26  (None, 12, 12, 64)   147648      add_26[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_46  (None, 12, 12, 64)   147648      add_47[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 12, 12, 64)   0           WideActivationResidualBlock_6[0][
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_26[0]
#                                                                  add_26[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_46[0]
#                                                                  add_47[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_7 ( (None, 12, 12, 64)   147648      add_6[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_27  (None, 12, 12, 64)   147648      add_27[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_47  (None, 12, 12, 64)   147648      add_48[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 12, 12, 64)   0           WideActivationResidualBlock_7[0][
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_27[0]
#                                                                  add_27[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_47[0]
#                                                                  add_48[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_8 ( (None, 12, 12, 64)   147648      add_7[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_28  (None, 12, 12, 64)   147648      add_28[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_48  (None, 12, 12, 64)   147648      add_49[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 12, 12, 64)   0           WideActivationResidualBlock_8[0][
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_28[0]
#                                                                  add_28[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_48[0]
#                                                                  add_49[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_9 ( (None, 12, 12, 64)   147648      add_8[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_29  (None, 12, 12, 64)   147648      add_29[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_49  (None, 12, 12, 64)   147648      add_50[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 12, 12, 64)   0           WideActivationResidualBlock_9[0][
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_29[0]
#                                                                  add_29[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_49[0]
#                                                                  add_50[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_10  (None, 12, 12, 64)   147648      add_9[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_30  (None, 12, 12, 64)   147648      add_30[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_50  (None, 12, 12, 64)   147648      add_51[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_10[0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_30[0]
#                                                                  add_30[0][0]
# __________________________________________________________________________________________________
# add_52 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_50[0]
#                                                                  add_51[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_11  (None, 12, 12, 64)   147648      add_10[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_31  (None, 12, 12, 64)   147648      add_31[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_51  (None, 12, 12, 64)   147648      add_52[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_11[0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_31[0]
#                                                                  add_31[0][0]
# __________________________________________________________________________________________________
# add_53 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_51[0]
#                                                                  add_52[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_12  (None, 12, 12, 64)   147648      add_11[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_32  (None, 12, 12, 64)   147648      add_32[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_52  (None, 12, 12, 64)   147648      add_53[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_12[0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_32[0]
#                                                                  add_32[0][0]
# __________________________________________________________________________________________________
# add_54 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_52[0]
#                                                                  add_53[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_13  (None, 12, 12, 64)   147648      add_12[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_33  (None, 12, 12, 64)   147648      add_33[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_53  (None, 12, 12, 64)   147648      add_54[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_13[0]
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_33[0]
#                                                                  add_33[0][0]
# __________________________________________________________________________________________________
# add_55 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_53[0]
#                                                                  add_54[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_14  (None, 12, 12, 64)   147648      add_13[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_34  (None, 12, 12, 64)   147648      add_34[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_54  (None, 12, 12, 64)   147648      add_55[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_14[0]
#                                                                  add_13[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_34[0]
#                                                                  add_34[0][0]
# __________________________________________________________________________________________________
# add_56 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_54[0]
#                                                                  add_55[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_15  (None, 12, 12, 64)   147648      add_14[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_35  (None, 12, 12, 64)   147648      add_35[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_55  (None, 12, 12, 64)   147648      add_56[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_15[0]
#                                                                  add_14[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_35[0]
#                                                                  add_35[0][0]
# __________________________________________________________________________________________________
# add_57 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_55[0]
#                                                                  add_56[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_16  (None, 12, 12, 64)   147648      add_15[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_36  (None, 12, 12, 64)   147648      add_36[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_56  (None, 12, 12, 64)   147648      add_57[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_16[0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_36[0]
#                                                                  add_36[0][0]
# __________________________________________________________________________________________________
# add_58 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_56[0]
#                                                                  add_57[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_17  (None, 12, 12, 64)   147648      add_16[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_37  (None, 12, 12, 64)   147648      add_37[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_57  (None, 12, 12, 64)   147648      add_58[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_17[0]
#                                                                  add_16[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_37[0]
#                                                                  add_37[0][0]
# __________________________________________________________________________________________________
# add_59 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_57[0]
#                                                                  add_58[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_18  (None, 12, 12, 64)   147648      add_17[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_38  (None, 12, 12, 64)   147648      add_38[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_58  (None, 12, 12, 64)   147648      add_59[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_18[0]
#                                                                  add_17[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_38[0]
#                                                                  add_38[0][0]
# __________________________________________________________________________________________________
# add_60 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_58[0]
#                                                                  add_59[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_19  (None, 12, 12, 64)   147648      add_18[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_39  (None, 12, 12, 64)   147648      add_39[0][0]
# __________________________________________________________________________________________________
# WideActivationResidualBlock_59  (None, 12, 12, 64)   147648      add_60[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_19[0]
#                                                                  add_18[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_39[0]
#                                                                  add_39[0][0]
# __________________________________________________________________________________________________
# add_61 (Add)                    (None, 12, 12, 64)   0           WideActivationResidualBlock_59[0]
#                                                                  add_60[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 12, 12, 64)   0           Y_DCT2C[0][0]
#                                                                  add_19[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 12, 12, 64)   0           Cr_DCT2C[0][0]
#                                                                  add_40[0][0]
# __________________________________________________________________________________________________
# add_62 (Add)                    (None, 12, 12, 64)   0           Cb_DCT2C[0][0]
#                                                                  add_61[0][0]
# __________________________________________________________________________________________________
# Y_C2DCT (Sequential)            (None, 96, 96, 1)    4097        add_20[0][0]
# __________________________________________________________________________________________________
# Cr_C2DCT (Sequential)           (None, 96, 96, 1)    4097        add_41[0][0]
# __________________________________________________________________________________________________
# Cb_C2DCT (Sequential)           (None, 96, 96, 1)    4097        add_62[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat (TensorFlowO [(None, 96, 96, 3)]  0           Y_C2DCT[0][0]
#                                                                  Cr_C2DCT[0][0]
#                                                                  Cb_C2DCT[0][0]
# ==================================================================================================
# Total params: 8,883,651
# Trainable params: 8,858,880
# Non-trainable params: 24,771
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ### Loading Dataset

# %%
#Loading the training dataset
train_x, train_y = utils.load_dataset("../dataset/train",  limit=None)

print("Loaded",train_x.shape[0], "samples")

#check the five firts samples   
utils.show_samples(train_x, train_y, begin=0, end=5)
# Out:
# 5246it [03:51, 22.61it/s]
# Loaded 5246 samples

# %%
#Loading the training dataset
valid_x, valid_y = utils.load_dataset("../dataset/valid",  limit=None)

print("Loaded",valid_x.shape[0], "samples")

#check the five firts samples   
utils.show_samples(valid_x, valid_y, begin=0, end=5)
# Out:
# 876it [00:48, 17.91it/s]
# Loaded 876 samples

# %% [markdown]
# ### Dataset shift and normalization

# %%
SHIFT_VALUE_X, SHIFT_VALUE_Y, SCALE_VALUE_X, SCALE_VALUE_Y = utils.get_shift_scale_maxmin(train_x, train_y, valid_x, valid_y)

train_x = utils.shift_and_normalize(train_x, SHIFT_VALUE_X, SCALE_VALUE_X)
train_y = utils.shift_and_normalize(train_y, SHIFT_VALUE_Y, SCALE_VALUE_Y)

valid_x = utils.shift_and_normalize(valid_x, SHIFT_VALUE_X, SCALE_VALUE_X)
valid_y = utils.shift_and_normalize(valid_y, SHIFT_VALUE_Y, SCALE_VALUE_Y)

# %% [markdown]
# ### Batches split

# %%
train_batches = utils.random_mini_batches(train_x, train_y, 8, seed=0)
valid_batches = utils.random_mini_batches(valid_x, valid_y, 8, seed=0)
print("train_batches:", len(train_batches), "valid_batches:", len(valid_batches))
# Out:
# train_batches: 656 valid_batches: 110

# %% [markdown]
# ### Metrics

# %%
#default tf.keras metrics
train_loss = tf.keras.metrics.Mean(name='train_loss')
valid_mse = tf.keras.metrics.MeanSquaredError(name='train_mse')

#psnr, ssim and nrmse
valid_custom_metrics = utils.CustomMetric()

# %% [markdown]
# ### Set Loss and load model weights

# %%
loss_object = tf.keras.losses.MeanSquaredError()
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

#get last saved epoch index and best result in validation step
CURRENT_EPOCH, BEST_VALIDATION = utils.get_model_last_data()
if CURRENT_EPOCH > 0:
    print("Loading last model state in epoch", CURRENT_EPOCH)
    model.load_weights(utils.get_exp_folder_last_epoch())
    print("Best validation result was SSIM=", BEST_VALIDATION)
# Out:
# Loading last model state in epoch 121
# Best validation result was SSIM= 0.8687423595638932

# %% [markdown]
# ### Training

# %%
@tf.function
def train_step(image_x, image_y):
    with tf.GradientTape() as tape:
        predictions = model(image_x)
        loss = loss_object(image_y, predictions)
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    train_loss(loss)

MAX_EPOCHS = 201
EVAL_STEP = 20

for epoch in range(CURRENT_EPOCH, MAX_EPOCHS):
    
    #TRAINING
    print("TRAINING EPOCH", epoch)
   
    for batch in train_batches:
        (batch_x, batch_y) = batch
        train_step(batch_x, batch_y)
    
    #VALIDATION
    if epoch%EVAL_STEP == 0 and epoch > 0:
        #tf.keras.backend.set_learning_phase(0)
        clear_output()
        
        print("VALIDATION EPOCH", epoch)
        #saving last epoch model
        model.save_weights(utils.get_exp_folder_last_epoch(), save_format='tf')
        for index, batch in enumerate(valid_batches):
            (batch_x, batch_y) = batch
            predictions = model(batch_x)
            valid_mse(batch_y, predictions)
            
            # convert back to original pattern
            batch_x = utils.inv_shift_and_normalize(batch_x.copy(), SHIFT_VALUE_X, SCALE_VALUE_X)
            batch_y = utils.inv_shift_and_normalize(batch_y.copy(), SHIFT_VALUE_Y, SCALE_VALUE_Y)
            predictions = utils.inv_shift_and_normalize(predictions.numpy(), SHIFT_VALUE_Y, SCALE_VALUE_Y)
            
            #convert from frequency to pixel-rgb domain
            batch_x, batch_y, predictions = utils.convert_batch_dct2rgb(batch_x, batch_y, predictions)
            
            #feed the metric evaluator
            valid_custom_metrics.feed(batch_y, predictions)
            
            #just show the first example of batch-0
            if index == 0:
                print("JPEG Q10 - JPEG Q50 - PREDICT")
                utils.preview_sample(batch_x[0], batch_y[0], predictions[0])
        
        #get metric results
        psnr, ssim, nrmse = valid_custom_metrics.result()
        valid_mse_result = valid_mse.result().numpy()
        
        utils.update_chart_data(epoch=epoch, train_mse=train_loss.result().numpy(), 
                                valid_mse=valid_mse_result, psnr=psnr, ssim=ssim, nrmse=nrmse)
        utils.draw_chart()
        
        #saving best validation model
        if ssim > BEST_VALIDATION:
            BEST_VALIDATION = ssim
            model.save_weights(utils.get_exp_folder_best_valid(), save_format='tf')
        
    train_loss.reset_states()
    valid_mse.reset_states()
    valid_custom_metrics.reset_states()
# Out:
# VALIDATION EPOCH 200
# JPEG Q10 - JPEG Q50 - PREDICT

# %% [markdown]
# ### Usage

# %%
img_index = 870
img_x = valid_x[img_index:(img_index+1)]
img_y = valid_y[img_index:(img_index+1)]
prediction = model(img_x)

img_x = utils.inv_shift_and_normalize(img_x.copy(), SHIFT_VALUE_X, SCALE_VALUE_X)
img_y = utils.inv_shift_and_normalize(img_y.copy(), SHIFT_VALUE_Y, SCALE_VALUE_Y)
prediction = utils.inv_shift_and_normalize(prediction.numpy(), SHIFT_VALUE_Y, SCALE_VALUE_Y)

#convert from frequency to pixel-rgb domain
img_x, img_y, prediction = utils.convert_batch_dct2rgb(img_x, img_y, prediction)
print("JPEG Q10 - JPEG Q50 - PREDICT")
utils.preview_sample(img_x[0], img_y[0], prediction[0])
# Out:
# JPEG Q10 - JPEG Q50 - PREDICT
